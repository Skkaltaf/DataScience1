# %% [markdown]
# <a href="https://colab.research.google.com/github/Skkaltaf/DataScience1/blob/main/file_different_type.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#The sender hasn't authenticated this message so Mahatma
Education Society Mail can't verify that it actually came from them.
Avoid clicking links, downloading attachments, or replying with
personal information.

# %%
import pandas as pd
data1 = pd.read_csv("Bowling_t20.csv")
data1
# Out:
#       Unnamed: 0                   Player       Span  Mat Inns  Overs Mdns  \
# 0              0          SL Malinga (SL)  2006-2019   79   79  284.5    1
# 1              1  Shahid Afridi (ICC/PAK)  2006-2018   99   97  361.2    4
# 2              2  Shakib Al Hasan (BDESH)  2006-2019   76   75  277.5    2
# 3              3        Saeed Ajmal (PAK)  2009-2015   64   63  238.2    2
# 4              4           Umar Gul (PAK)  2007-2016   60   60  200.3    2
# ...          ...                      ...        ...  ...  ...    ...  ...
# 2001           1       Ziaur Rehman (Fin)  2019-2019    1    -      -    -
# 2002           2        Zishan Shah (DEN)  2019-2019    6    -      -    -
# 2003           3   Zubaidi Zulkifle (MAL)  2019-2019    4    -      -    -
# 2004           4         B Zuiderent (NL)  2009-2010    6    -      -    -
# 2005           5  Zulqarnain Haider (PAK)  2007-2010    3    -      -    -
#
#       Runs Wkts   BBI    Ave  Econ    SR  4  5  Unnamed: 14
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.image as img1
img2=img1.imread("/content/Phoenicopterus_ruber_in_São_Paulo_Zoo.jpg")
plt.imshow(img2)

# %%
import pandas as pd
df=pd.DataFrame({"Sr.no":[1,2,3,4,5],"Roll No":[365,653,62,625,5441],"Name":["A","B","C","D","E"]})
df
# Out:
#    Sr.no  Roll No Name
# 0      1      365    A
# 1      2      653    B
# 2      3       62    C
# 3      4      625    D
# 4      5     5441    E

# %%
import pandas as pd
data2=pd.read_excel("first.xlsx")
data2
# Out:
#        s                        Player       Span  Mat Inns  Balls   Runs  \
# 0      0  M Muralitharan (Asia/ICC/SL)  1993-2011  350  341  18811  12326
# 1      1             Wasim Akram (PAK)  1984-2003  356  351  18186  11812
# 2      2            Waqar Younis (PAK)  1989-2003  262  258  12698   9919
# 3      3          WPUJC Vaas (Asia/SL)  1994-2008  322  320  15775  11014
# 4      4  Shahid Afridi (Asia/ICC/PAK)  1996-2015  398  372  17670  13632
# ...   ..                           ...        ...  ...  ...    ...    ...
# 2577  27              TJ Zoehrer (AUS)  1986-1994   22    -      -      -
# 2578  28                  K Zondo (SA)  2018-2018    5    -      -      -
# 2579  29              B Zuiderent (NL)  1996-2011   57    -      -      -
# 2580  30              Zulqarnain (PAK)  1985-1989   16    -      -      -
# 2581  31       Zulqarnain Haider (PAK)  2010-2010    4    -      -      -
#
#      Wkts                  BBI    Ave  Econ    SR   4   5  Unnamed: 13
# ...

# %%
df.isnull().sum()
# Out:
# Sr.no      0
# Roll No    0
# Name       0
# dtype: int64
